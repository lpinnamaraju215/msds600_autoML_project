# %% [markdown]
# # DS Automation Assignment

# %% [markdown]
# Using our prepared churn data from week 2:
# - use pycaret to find an ML algorithm that performs best on the data
#     - Choose a metric you think is best to use for finding the best model; by default, it is accuracy but it could be AUC, precision, recall, etc. The week 3 FTE has some information on these different metrics.
# - save the model to disk
# - create a Python script/file/module with a function that takes a pandas dataframe as an input and returns the probability of churn for each row in the dataframe
#     - your Python file/function should print out the predictions for new data (new_churn_data.csv)
#     - the true values for the new data are [1, 0, 0, 1, 0] if you're interested
# - test your Python module and function with the new data, new_churn_data.csv
# - write a short summary of the process and results at the end of this notebook
# - upload this Jupyter Notebook and Python file to a Github repository, and turn in a link to the repository in the week 5 assignment dropbox
#
# *Optional* challenges:
# - return the probability of churn for each new prediction, and the percentile where that prediction is in the distribution of probability predictions from the training dataset (e.g. a high probability of churn like 0.78 might be at the 90th percentile)
# - use other autoML packages, such as TPOT, H2O, MLBox, etc, and compare performance and features with pycaret
# - create a class in your Python module to hold the functions that you created
# - accept user input to specify a file using a tool such as Python's `input()` function, the `click` package for command-line arguments, or a GUI
# - Use the unmodified churn data (new_unmodified_churn_data.csv) in your Python script. This will require adding the same preprocessing steps from week 2 since this data is like the original unmodified dataset from week 1.

# %% [markdown]
# LOAD DATA:

# %%
import pandas as pd

# reading csv file into data frame and naming the index column
df = pd.read_csv('prepped_churn_data.csv', index_col='customerID')
df
# Out:
#             tenure  PhoneService  Contract  PaymentMethod  MonthlyCharges  \
# customerID
# 7590-VHVEG     1.0             0         0              0           29.85
# 5575-GNVDE    34.0             1         1              1           56.95
# 3668-QPYBK     2.0             1         0              1           53.85
# 7795-CFOCW    45.0             0         1              2           42.30
# 9237-HQITU     2.0             1         0              0           70.70
# ...            ...           ...       ...            ...             ...
# 6840-RESVB    24.0             1         1              1           84.80
# 2234-XADUH    72.0             1         1              3          103.20
# 4801-JZAZL    11.0             0         0              0           29.60
# 8361-LTMKD     4.0             1         0              1           74.40
# 3186-AJIEK    66.0             1         2              2          105.65
#
#             TotalCharges  Churn  yj_tenure  Total_tenure_ratio
# customerID
# 7590-VHVEG         29.85      0  -1.644343           29.850000
# 5575-GNVDE       1889.50      0   0.297205           55.573529
# 3668-QPYBK        108.15      1  -1.495444           54.075000
# 7795-CFOCW       1840.75      0   0.646327           40.905556
# 9237-HQITU        151.65      1  -1.495444           75.825000
# ...                  ...    ...        ...                 ...
# 6840-RESVB       1990.50      0  -0.078084           82.937500
# 2234-XADUH       7362.90      0   1.342198          102.262500
# 4801-JZAZL        346.45      0  -0.725121           31.495455
# 8361-LTMKD        306.60      1  -1.265130           76.650000
# 3186-AJIEK       6844.50      0   1.201896          103.704545
#
# [7043 rows x 9 columns]

# %%
del df['yj_tenure']

# %%
del df['Total_tenure_ratio']

# %% [markdown]
# AutoML WITH PYCARET:

# %%
pip install pycaret
# Out:
# Requirement already satisfied: pycaret in e:\softwares\anaconda3\lib\site-packages (2.2.2)
# Requirement already satisfied: IPython in e:\softwares\anaconda3\lib\site-packages (from pycaret) (7.29.0)
# Requirement already satisfied: joblib in e:\softwares\anaconda3\lib\site-packages (from pycaret) (1.1.0)
# Requirement already satisfied: mlflow in e:\softwares\anaconda3\lib\site-packages (from pycaret) (1.23.1)
# Requirement already satisfied: catboost>=0.23.2 in e:\softwares\anaconda3\lib\site-packages (from pycaret) (1.0.4)
# Requirement already satisfied: pyod in e:\softwares\anaconda3\lib\site-packages (from pycaret) (0.9.7)
# Requirement already satisfied: yellowbrick>=1.0.1 in e:\softwares\anaconda3\lib\site-packages (from pycaret) (1.3.post1)
# Requirement already satisfied: scikit-plot in e:\softwares\anaconda3\lib\site-packages (from pycaret) (0.3.7)
# Requirement already satisfied: textblob in e:\softwares\anaconda3\lib\site-packages (from pycaret) (0.15.3)
# Requirement already satisfied: umap-learn in e:\softwares\anaconda3\lib\site-packages (from pycaret) (0.5.2)
# Requirement already satisfied: ipywidgets in e:\softwares\anaconda3\lib\site-packages (from pycaret) (7.6.5)
# Requirement already satisfied: plotly>=4.4.1 in e:\softwares\anaconda3\lib\site-packages (from pycaret) (5.6.0)
# Requirement already satisfied: pyLDAvis in e:\softwares\anaconda3\lib\site-packages (from pycaret) (3.2.2)
# Requirement already satisfied: spacy in e:\softwares\anaconda3\lib\site-packages (from pycaret) (2.3.7)
# Requirement already satisfied: wordcloud in e:\softwares\anaconda3\lib\site-packages (from pycaret) (1.8.1)
# Requirement already satisfied: pandas in e:\softwares\anaconda3\lib\site-packages (from pycaret) (1.3.4)
# Requirement already satisfied: seaborn in e:\softwares\anaconda3\lib\site-packages (from pycaret) (0.11.2)
# Requirement already satisfied: nltk in e:\softwares\anaconda3\lib\site-packages (from pycaret) (3.6.5)
# Requirement already satisfied: xgboost>=1.1.0 in e:\softwares\anaconda3\lib\site-packages (from pycaret) (1.5.2)
# Requirement already satisfied: mlxtend in e:\softwares\anaconda3\lib\site-packages (from pycaret) (0.19.0)
# Requirement already satisfied: matplotlib in e:\softwares\anaconda3\lib\site-packages (from pycaret) (3.4.3)
# Requirement already satisfied: scikit-learn>=0.23.2 in e:\softwares\anaconda3\lib\site-packages (from pycaret) (0.24.2)
# Requirement already satisfied: kmodes>=0.10.1 in e:\softwares\anaconda3\lib\site-packages (from pycaret) (0.11.1)
# Requirement already satisfied: imbalanced-learn>=0.7.0 in e:\softwares\anaconda3\lib\site-packages (from pycaret) (0.8.1)
# Requirement already satisfied: gensim in e:\softwares\anaconda3\lib\site-packages (from pycaret) (4.0.1)
# Requirement already satisfied: cufflinks>=0.17.0 in e:\softwares\anaconda3\lib\site-packages (from pycaret) (0.17.3)
# Requirement already satisfied: numpy>=1.17 in e:\softwares\anaconda3\lib\site-packages (from pycaret) (1.19.5)
# Requirement already satisfied: lightgbm>=2.3.1 in e:\softwares\anaconda3\lib\site-packages (from pycaret) (3.3.2)
# Requirement already satisfied: pandas-profiling>=2.8.0 in e:\softwares\anaconda3\lib\site-packages (from pycaret) (2.8.0)
# Requirement already satisfied: six in e:\softwares\anaconda3\lib\site-packages (from catboost>=0.23.2->pycaret) (1.16.0)
# Requirement already satisfied: scipy in e:\softwares\anaconda3\lib\site-packages (from catboost>=0.23.2->pycaret) (1.7.1)
# Requirement already satisfied: graphviz in e:\softwares\anaconda3\lib\site-packages (from catboost>=0.23.2->pycaret) (0.19.1)
# Requirement already satisfied: setuptools>=34.4.1 in e:\softwares\anaconda3\lib\site-packages (from cufflinks>=0.17.0->pycaret) (58.0.4)
# Requirement already satisfied: colorlover>=0.2.1 in e:\softwares\anaconda3\lib\site-packages (from cufflinks>=0.17.0->pycaret) (0.3.0)
# Requirement already satisfied: jedi>=0.16 in e:\softwares\anaconda3\lib\site-packages (from IPython->pycaret) (0.18.0)
# Requirement already satisfied: backcall in e:\softwares\anaconda3\lib\site-packages (from IPython->pycaret) (0.2.0)
# Requirement already satisfied: traitlets>=4.2 in e:\softwares\anaconda3\lib\site-packages (from IPython->pycaret) (5.1.0)
# Requirement already satisfied: matplotlib-inline in e:\softwares\anaconda3\lib\site-packages (from IPython->pycaret) (0.1.2)
# Requirement already satisfied: pickleshare in e:\softwares\anaconda3\lib\site-packages (from IPython->pycaret) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in e:\softwares\anaconda3\lib\site-packages (from IPython->pycaret) (3.0.20)
# Requirement already satisfied: colorama in e:\softwares\anaconda3\lib\site-packages (from IPython->pycaret) (0.4.4)
# Requirement already satisfied: decorator in e:\softwares\anaconda3\lib\site-packages (from IPython->pycaret) (5.1.0)
# Requirement already satisfied: pygments in e:\softwares\anaconda3\lib\site-packages (from IPython->pycaret) (2.10.0)
# Requirement already satisfied: ipykernel>=4.5.1 in e:\softwares\anaconda3\lib\site-packages (from ipywidgets->pycaret) (6.4.1)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in e:\softwares\anaconda3\lib\site-packages (from ipywidgets->pycaret) (1.0.0)
# Requirement already satisfied: nbformat>=4.2.0 in e:\softwares\anaconda3\lib\site-packages (from ipywidgets->pycaret) (5.1.3)
# Requirement already satisfied: ipython-genutils~=0.2.0 in e:\softwares\anaconda3\lib\site-packages (from ipywidgets->pycaret) (0.2.0)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in e:\softwares\anaconda3\lib\site-packages (from ipywidgets->pycaret) (3.5.1)
# Requirement already satisfied: jupyter-client<8.0 in e:\softwares\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets->pycaret) (6.1.12)
# Requirement already satisfied: tornado<7.0,>=4.2 in e:\softwares\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets->pycaret) (6.1)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in e:\softwares\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets->pycaret) (1.4.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in e:\softwares\anaconda3\lib\site-packages (from jedi>=0.16->IPython->pycaret) (0.8.2)
# Requirement already satisfied: pyzmq>=13 in e:\softwares\anaconda3\lib\site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets->pycaret) (22.2.1)
# Requirement already satisfied: python-dateutil>=2.1 in e:\softwares\anaconda3\lib\site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets->pycaret) (2.8.2)
# Requirement already satisfied: jupyter-core>=4.6.0 in e:\softwares\anaconda3\lib\site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets->pycaret) (4.8.1)
# Requirement already satisfied: pywin32>=1.0 in e:\softwares\anaconda3\lib\site-packages (from jupyter-core>=4.6.0->jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets->pycaret) (228)
# Requirement already satisfied: wheel in e:\softwares\anaconda3\lib\site-packages (from lightgbm>=2.3.1->pycaret) (0.37.0)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in e:\softwares\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets->pycaret) (3.2.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in e:\softwares\anaconda3\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets->pycaret) (0.18.0)
# Requirement already satisfied: attrs>=17.4.0 in e:\softwares\anaconda3\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets->pycaret) (21.2.0)
# Requirement already satisfied: pytz>=2017.3 in e:\softwares\anaconda3\lib\site-packages (from pandas->pycaret) (2021.3)
# Requirement already satisfied: confuse>=1.0.0 in e:\softwares\anaconda3\lib\site-packages (from pandas-profiling>=2.8.0->pycaret) (1.7.0)
# Requirement already satisfied: tqdm>=4.43.0 in e:\softwares\anaconda3\lib\site-packages (from pandas-profiling>=2.8.0->pycaret) (4.62.3)
# Requirement already satisfied: htmlmin>=0.1.12 in e:\softwares\anaconda3\lib\site-packages (from pandas-profiling>=2.8.0->pycaret) (0.1.12)
# Requirement already satisfied: astropy>=4.0 in e:\softwares\anaconda3\lib\site-packages (from pandas-profiling>=2.8.0->pycaret) (4.3.1)
# Requirement already satisfied: missingno>=0.4.2 in e:\softwares\anaconda3\lib\site-packages (from pandas-profiling>=2.8.0->pycaret) (0.4.2)
# Requirement already satisfied: jinja2>=2.11.1 in e:\softwares\anaconda3\lib\site-packages (from pandas-profiling>=2.8.0->pycaret) (2.11.3)
# Requirement already satisfied: tangled-up-in-unicode>=0.0.6 in e:\softwares\anaconda3\lib\site-packages (from pandas-profiling>=2.8.0->pycaret) (0.2.0)
# Requirement already satisfied: requests>=2.23.0 in e:\softwares\anaconda3\lib\site-packages (from pandas-profiling>=2.8.0->pycaret) (2.26.0)
# Requirement already satisfied: phik>=0.9.10 in e:\softwares\anaconda3\lib\site-packages (from pandas-profiling>=2.8.0->pycaret) (0.12.0)
# Requirement already satisfied: visions[type_image_path]==0.4.4 in e:\softwares\anaconda3\lib\site-packages (from pandas-profiling>=2.8.0->pycaret) (0.4.4)
# Requirement already satisfied: networkx>=2.4 in e:\softwares\anaconda3\lib\site-packages (from visions[type_image_path]==0.4.4->pandas-profiling>=2.8.0->pycaret) (2.6.3)
# Requirement already satisfied: imagehash in e:\softwares\anaconda3\lib\site-packages (from visions[type_image_path]==0.4.4->pandas-profiling>=2.8.0->pycaret) (4.2.1)
# Requirement already satisfied: Pillow in e:\softwares\anaconda3\lib\site-packages (from visions[type_image_path]==0.4.4->pandas-profiling>=2.8.0->pycaret) (8.4.0)
# Requirement already satisfied: pyerfa>=1.7.3 in e:\softwares\anaconda3\lib\site-packages (from astropy>=4.0->pandas-profiling>=2.8.0->pycaret) (2.0.0)
# Requirement already satisfied: pyyaml in e:\softwares\anaconda3\lib\site-packages (from confuse>=1.0.0->pandas-profiling>=2.8.0->pycaret) (6.0)
# Requirement already satisfied: MarkupSafe>=0.23 in e:\softwares\anaconda3\lib\site-packages (from jinja2>=2.11.1->pandas-profiling>=2.8.0->pycaret) (1.1.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in e:\softwares\anaconda3\lib\site-packages (from matplotlib->pycaret) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in e:\softwares\anaconda3\lib\site-packages (from matplotlib->pycaret) (0.10.0)
# Requirement already satisfied: pyparsing>=2.2.1 in e:\softwares\anaconda3\lib\site-packages (from matplotlib->pycaret) (3.0.4)
# Requirement already satisfied: tenacity>=6.2.0 in e:\softwares\anaconda3\lib\site-packages (from plotly>=4.4.1->pycaret) (8.0.1)
# Requirement already satisfied: wcwidth in e:\softwares\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->IPython->pycaret) (0.2.5)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in e:\softwares\anaconda3\lib\site-packages (from requests>=2.23.0->pandas-profiling>=2.8.0->pycaret) (1.26.7)
# Requirement already satisfied: certifi>=2017.4.17 in e:\softwares\anaconda3\lib\site-packages (from requests>=2.23.0->pandas-profiling>=2.8.0->pycaret) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in e:\softwares\anaconda3\lib\site-packages (from requests>=2.23.0->pandas-profiling>=2.8.0->pycaret) (3.2)
# Requirement already satisfied: charset-normalizer~=2.0.0 in e:\softwares\anaconda3\lib\site-packages (from requests>=2.23.0->pandas-profiling>=2.8.0->pycaret) (2.0.4)
# Requirement already satisfied: threadpoolctl>=2.0.0 in e:\softwares\anaconda3\lib\site-packages (from scikit-learn>=0.23.2->pycaret) (2.2.0)
# Requirement already satisfied: notebook>=4.4.1 in e:\softwares\anaconda3\lib\site-packages (from widgetsnbextension~=3.5.0->ipywidgets->pycaret) (6.4.5)
# Requirement already satisfied: terminado>=0.8.3 in e:\softwares\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (0.9.4)
# Requirement already satisfied: nbconvert in e:\softwares\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (6.1.0)
# Requirement already satisfied: prometheus-client in e:\softwares\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (0.11.0)
# Requirement already satisfied: argon2-cffi in e:\softwares\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (20.1.0)
# Requirement already satisfied: Send2Trash>=1.5.0 in e:\softwares\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (1.8.0)
# Requirement already satisfied: pywinpty>=0.5 in e:\softwares\anaconda3\lib\site-packages (from terminado>=0.8.3->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (0.5.7)
# Requirement already satisfied: cffi>=1.0.0 in e:\softwares\anaconda3\lib\site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (1.14.6)
# Requirement already satisfied: pycparser in e:\softwares\anaconda3\lib\site-packages (from cffi>=1.0.0->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (2.20)
# Requirement already satisfied: smart-open>=1.8.1 in e:\softwares\anaconda3\lib\site-packages (from gensim->pycaret) (5.2.1)
# Requirement already satisfied: PyWavelets in e:\softwares\anaconda3\lib\site-packages (from imagehash->visions[type_image_path]==0.4.4->pandas-profiling>=2.8.0->pycaret) (1.1.1)
# Requirement already satisfied: databricks-cli>=0.8.7 in e:\softwares\anaconda3\lib\site-packages (from mlflow->pycaret) (0.12.1)
# Requirement already satisfied: docker>=4.0.0 in e:\softwares\anaconda3\lib\site-packages (from mlflow->pycaret) (5.0.3)
# Requirement already satisfied: cloudpickle in e:\softwares\anaconda3\lib\site-packages (from mlflow->pycaret) (2.0.0)
# Requirement already satisfied: entrypoints in e:\softwares\anaconda3\lib\site-packages (from mlflow->pycaret) (0.3)
# Requirement already satisfied: prometheus-flask-exporter in e:\softwares\anaconda3\lib\site-packages (from mlflow->pycaret) (0.18.7)
# Requirement already satisfied: Flask in e:\softwares\anaconda3\lib\site-packages (from mlflow->pycaret) (1.1.2)
# Requirement already satisfied: protobuf>=3.7.0 in e:\softwares\anaconda3\lib\site-packages (from mlflow->pycaret) (3.18.0)
# Requirement already satisfied: gitpython>=2.1.0 in e:\softwares\anaconda3\lib\site-packages (from mlflow->pycaret) (3.1.26)
# Requirement already satisfied: importlib-metadata!=4.7.0,>=3.7.0 in e:\softwares\anaconda3\lib\site-packages (from mlflow->pycaret) (4.8.1)
# Requirement already satisfied: sqlalchemy in e:\softwares\anaconda3\lib\site-packages (from mlflow->pycaret) (1.4.22)
# Requirement already satisfied: sqlparse>=0.3.1 in e:\softwares\anaconda3\lib\site-packages (from mlflow->pycaret) (0.4.2)
# Requirement already satisfied: packaging in e:\softwares\anaconda3\lib\site-packages (from mlflow->pycaret) (21.0)
# Requirement already satisfied: alembic in e:\softwares\anaconda3\lib\site-packages (from mlflow->pycaret) (1.7.6)
# Requirement already satisfied: querystring-parser in e:\softwares\anaconda3\lib\site-packages (from mlflow->pycaret) (1.2.4)
# Requirement already satisfied: click>=7.0 in e:\softwares\anaconda3\lib\site-packages (from mlflow->pycaret) (8.0.3)
# Requirement already satisfied: waitress in e:\softwares\anaconda3\lib\site-packages (from mlflow->pycaret) (2.0.0)
# Requirement already satisfied: tabulate>=0.7.7 in e:\softwares\anaconda3\lib\site-packages (from databricks-cli>=0.8.7->mlflow->pycaret) (0.8.9)
# Requirement already satisfied: websocket-client>=0.32.0 in e:\softwares\anaconda3\lib\site-packages (from docker>=4.0.0->mlflow->pycaret) (1.2.3)
# Requirement already satisfied: gitdb<5,>=4.0.1 in e:\softwares\anaconda3\lib\site-packages (from gitpython>=2.1.0->mlflow->pycaret) (4.0.9)
# Requirement already satisfied: smmap<6,>=3.0.1 in e:\softwares\anaconda3\lib\site-packages (from gitdb<5,>=4.0.1->gitpython>=2.1.0->mlflow->pycaret) (3.0.5)
# Requirement already satisfied: zipp>=0.5 in e:\softwares\anaconda3\lib\site-packages (from importlib-metadata!=4.7.0,>=3.7.0->mlflow->pycaret) (3.6.0)
# Requirement already satisfied: Mako in e:\softwares\anaconda3\lib\site-packages (from alembic->mlflow->pycaret) (1.1.6)
# Requirement already satisfied: greenlet!=0.4.17 in e:\softwares\anaconda3\lib\site-packages (from sqlalchemy->mlflow->pycaret) (1.1.1)
# Requirement already satisfied: itsdangerous>=0.24 in e:\softwares\anaconda3\lib\site-packages (from Flask->mlflow->pycaret) (2.0.1)
# Requirement already satisfied: Werkzeug>=0.15 in e:\softwares\anaconda3\lib\site-packages (from Flask->mlflow->pycaret) (2.0.2)
# Requirement already satisfied: defusedxml in e:\softwares\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (0.7.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in e:\softwares\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (0.8.4)
# Requirement already satisfied: testpath in e:\softwares\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (0.5.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in e:\softwares\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (1.4.3)
# Requirement already satisfied: jupyterlab-pygments in e:\softwares\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (0.1.2)
# Requirement already satisfied: bleach in e:\softwares\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (4.0.0)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in e:\softwares\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (0.5.3)
# Requirement already satisfied: async-generator in e:\softwares\anaconda3\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (1.10)
# Requirement already satisfied: nest-asyncio in e:\softwares\anaconda3\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (1.5.1)
# Requirement already satisfied: webencodings in e:\softwares\anaconda3\lib\site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (0.5.1)
# Requirement already satisfied: regex>=2021.8.3 in e:\softwares\anaconda3\lib\site-packages (from nltk->pycaret) (2021.8.3)
# Requirement already satisfied: numexpr in e:\softwares\anaconda3\lib\site-packages (from pyLDAvis->pycaret) (2.7.3)
# Requirement already satisfied: funcy in e:\softwares\anaconda3\lib\site-packages (from pyLDAvis->pycaret) (1.17)Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: future in e:\softwares\anaconda3\lib\site-packages (from pyLDAvis->pycaret) (0.18.2)
# Requirement already satisfied: statsmodels in e:\softwares\anaconda3\lib\site-packages (from pyod->pycaret) (0.12.2)
# Requirement already satisfied: numba>=0.35 in e:\softwares\anaconda3\lib\site-packages (from pyod->pycaret) (0.54.1)
# Requirement already satisfied: llvmlite<0.38,>=0.37.0rc1 in e:\softwares\anaconda3\lib\site-packages (from numba>=0.35->pyod->pycaret) (0.37.0)
# Requirement already satisfied: thinc<7.5.0,>=7.4.1 in e:\softwares\anaconda3\lib\site-packages (from spacy->pycaret) (7.4.5)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in e:\softwares\anaconda3\lib\site-packages (from spacy->pycaret) (2.0.6)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in e:\softwares\anaconda3\lib\site-packages (from spacy->pycaret) (0.9.0)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in e:\softwares\anaconda3\lib\site-packages (from spacy->pycaret) (0.7.5)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in e:\softwares\anaconda3\lib\site-packages (from spacy->pycaret) (3.0.6)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in e:\softwares\anaconda3\lib\site-packages (from spacy->pycaret) (1.0.6)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in e:\softwares\anaconda3\lib\site-packages (from spacy->pycaret) (0.9.6)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in e:\softwares\anaconda3\lib\site-packages (from spacy->pycaret) (1.0.0)
# Requirement already satisfied: srsly<1.1.0,>=1.0.2 in e:\softwares\anaconda3\lib\site-packages (from spacy->pycaret) (1.0.5)
# Requirement already satisfied: patsy>=0.5 in e:\softwares\anaconda3\lib\site-packages (from statsmodels->pyod->pycaret) (0.5.2)
# Requirement already satisfied: pynndescent>=0.5 in e:\softwares\anaconda3\lib\site-packages (from umap-learn->pycaret) (0.5.6)

# %%
pip install scikit-plot
# Out:
# Requirement already satisfied: scikit-plot in e:\softwares\anaconda3\lib\site-packages (0.3.7)
# Requirement already satisfied: scipy>=0.9 in e:\softwares\anaconda3\lib\site-packages (from scikit-plot) (1.7.1)
# Requirement already satisfied: matplotlib>=1.4.0 in e:\softwares\anaconda3\lib\site-packages (from scikit-plot) (3.4.3)
# Requirement already satisfied: scikit-learn>=0.18 in e:\softwares\anaconda3\lib\site-packages (from scikit-plot) (0.24.2)
# Requirement already satisfied: joblib>=0.10 in e:\softwares\anaconda3\lib\site-packages (from scikit-plot) (1.1.0)
# Requirement already satisfied: numpy>=1.16 in e:\softwares\anaconda3\lib\site-packages (from matplotlib>=1.4.0->scikit-plot) (1.19.5)
# Requirement already satisfied: pillow>=6.2.0 in e:\softwares\anaconda3\lib\site-packages (from matplotlib>=1.4.0->scikit-plot) (8.4.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in e:\softwares\anaconda3\lib\site-packages (from matplotlib>=1.4.0->scikit-plot) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in e:\softwares\anaconda3\lib\site-packages (from matplotlib>=1.4.0->scikit-plot) (0.10.0)
# Requirement already satisfied: python-dateutil>=2.7 in e:\softwares\anaconda3\lib\site-packages (from matplotlib>=1.4.0->scikit-plot) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in e:\softwares\anaconda3\lib\site-packages (from matplotlib>=1.4.0->scikit-plot) (3.0.4)
# Requirement already satisfied: six in e:\softwares\anaconda3\lib\site-packages (from cycler>=0.10->matplotlib>=1.4.0->scikit-plot) (1.16.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in e:\softwares\anaconda3\lib\site-packages (from scikit-learn>=0.18->scikit-plot) (2.2.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
#importing specific functions from pycaret
from pycaret.classification import setup, compare_models, predict_model, save_model, load_model

# %%
#setup function must be called before execution of any other function
automl = setup(df, target='Churn', fold_shuffle=True, preprocess=False)#setup() takes two important parameters like data and target
# Out:
# <style type="text/css">
# </style>
# <table id="T_feeae_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Description</th>
#       <th class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_feeae_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_feeae_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_feeae_row0_col1" class="data row0 col1" >4219</td>
#     </tr>
#     <tr>
#       <th id="T_feeae_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_feeae_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_feeae_row1_col1" class="data row1 col1" >Churn</td>
#     </tr>
#     <tr>
#       <th id="T_feeae_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_feeae_row2_col0" class="data row2 col0" >Target Type</td>
#       <td id="T_feeae_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_feeae_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_feeae_row3_col0" class="data row3 col0" >Label Encoded</td>
#       <td id="T_feeae_row3_col1" class="data row3 col1" >0: 0, 1: 1</td>
#     </tr>
#     <tr>
#       <th id="T_feeae_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_feeae_row4_col0" class="data row4 col0" >Original Data</td>
#       <td id="T_feeae_row4_col1" class="data row4 col1" >(7043, 7)</td>
#     </tr>
#     <tr>
#       <th id="T_feeae_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_feeae_row5_col0" class="data row5 col0" >Missing Values</td>
#       <td id="T_feeae_row5_col1" class="data row5 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_feeae_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_feeae_row6_col0" class="data row6 col0" >Numeric Features</td>
#       <td id="T_feeae_row6_col1" class="data row6 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_feeae_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_feeae_row7_col0" class="data row7 col0" >Categorical Features</td>
#       <td id="T_feeae_row7_col1" class="data row7 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_feeae_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_feeae_row8_col0" class="data row8 col0" >Transformed Train Set</td>
#       <td id="T_feeae_row8_col1" class="data row8 col1" >(4930, 6)</td>
#     </tr>
#     <tr>
#       <th id="T_feeae_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_feeae_row9_col0" class="data row9 col0" >Transformed Test Set</td>
#       <td id="T_feeae_row9_col1" class="data row9 col1" >(2113, 6)</td>
#     </tr>
#     <tr>
#       <th id="T_feeae_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_feeae_row10_col0" class="data row10 col0" >Shuffle Train-Test</td>
#       <td id="T_feeae_row10_col1" class="data row10 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_feeae_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_feeae_row11_col0" class="data row11 col0" >Stratify Train-Test</td>
#       <td id="T_feeae_row11_col1" class="data row11 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_feeae_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_feeae_row12_col0" class="data row12 col0" >Fold Generator</td>
#       <td id="T_feeae_row12_col1" class="data row12 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_feeae_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_feeae_row13_col0" class="data row13 col0" >Fold Number</td>
#       <td id="T_feeae_row13_col1" class="data row13 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_feeae_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_feeae_row14_col0" class="data row14 col0" >CPU Jobs</td>
#       <td id="T_feeae_row14_col1" class="data row14 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_feeae_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_feeae_row15_col0" class="data row15 col0" >Use GPU</td>
#       <td id="T_feeae_row15_col1" class="data row15 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_feeae_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_feeae_row16_col0" class="data row16 col0" >Log Experiment</td>
#       <td id="T_feeae_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_feeae_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_feeae_row17_col0" class="data row17 col0" >Experiment Name</td>
#       <td id="T_feeae_row17_col1" class="data row17 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_feeae_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_feeae_row18_col0" class="data row18 col0" >USI</td>
#       <td id="T_feeae_row18_col1" class="data row18 col1" >e75f</td>
#     </tr>
#     <tr>
#       <th id="T_feeae_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_feeae_row19_col0" class="data row19 col0" >Fix Imbalance</td>
#       <td id="T_feeae_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_feeae_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_feeae_row20_col0" class="data row20 col0" >Fix Imbalance Method</td>
#       <td id="T_feeae_row20_col1" class="data row20 col1" >SMOTE</td>
#     </tr>
#   </tbody>
# </table>

# %%
automl[7]
# Out:
# False

# %%
#compare_models() evaluates the performance of all models using cross-validation
best_model = compare_models(sort='F1')#here sort is used to consider 'F1' as the scoring metric(by default accuracy)
# Out:
# <style type="text/css">
# #T_ba1b5_ th {
#   text-align: left;
# }
# #T_ba1b5_row0_col0, #T_ba1b5_row0_col1, #T_ba1b5_row0_col2, #T_ba1b5_row0_col3, #T_ba1b5_row0_col4, #T_ba1b5_row1_col0, #T_ba1b5_row1_col1, #T_ba1b5_row1_col2, #T_ba1b5_row1_col4, #T_ba1b5_row1_col5, #T_ba1b5_row1_col6, #T_ba1b5_row1_col7, #T_ba1b5_row2_col0, #T_ba1b5_row2_col1, #T_ba1b5_row2_col2, #T_ba1b5
td>
#     </tr>
#     <tr>
#       <th id="T_ba1b5_level0_row5" class="row_heading level0 row5" >lda</th>
#       <td id="T_ba1b5_row5_col0" class="data row5 col0" >Linear Discriminant Analysis</td>
#       <td id="T_ba1b5_row5_col1" class="data row5 col1" >0.7832</td>
#       <td id="T_ba1b5_row5_col2" class="data row5 col2" >0.8189</td>
#       <td id="T_ba1b5_row5_col3" class="data row5 col3" >0.5000</td>
#       <td id="T_ba1b5_row5_col4" class="data row5 col4" >0.6290</td>
#       <td id="T_ba1b5_row5_col5" class="data row5 col5" >0.5561</td>
#       <td id="T_ba1b5_row5_col6" class="data row5 col6" >0.4154</td>
#       <td id="T_ba1b5_row5_col7" class="data row5 col7" >0.4207</td>
#       <td id="T_ba1b5_row5_col8" class="data ro

# %%
#used to display the best model
best_model
# Out:
# QuadraticDiscriminantAnalysis(priors=None, reg_param=0.0,
#                               store_covariance=False, tol=0.0001)

# %%
#iloc() function is used to fetch records based on the index values from the dataset
df.iloc[-1].shape #df.shape() gives the number of rows and columns(returns 1-D array)
# Out:
# (7,)

# %%
#returns 2-D array because -2:-1 represents a range(it represents line)
df.iloc[-2:-1].shape
# Out:
# (1, 7)

# %%
#predicts label and score using a trained model
predict_model(best_model, df.iloc[-2:-1])
# Out:
#             tenure  PhoneService  Contract  PaymentMethod  MonthlyCharges  \
# customerID
# 8361-LTMKD     4.0             1         0              1            74.4
#
#             TotalCharges  Churn  Label   Score
# customerID
# 8361-LTMKD         306.6      1      1  0.9089

# %% [markdown]
# SAVING AND LOADING OUR MODEL:

# %%
#save_model() is used to save our trained model( or best model)
save_model(best_model, 'QDA')
# Out:
# Transformation Pipeline and Model Succesfully Saved
# (Pipeline(memory=None,
#           steps=[('dtypes',
#                   DataTypes_Auto_infer(categorical_features=[],
#                                        display_types=True, features_todrop=[],
#                                        id_columns=[],
#                                        ml_usecase='classification',
#                                        numerical_features=[], target='Churn',
#                                        time_features=[])),
#                  ['trained_model',
#                   QuadraticDiscriminantAnalysis(priors=None, reg_param=0.0,
#                                                 store_covariance=False,
#                                                 tol=0.0001)]],
#           verbose=False),
#  'QDA.pkl')

# %%
#pickle module is used for saving and loading the data
import pickle
#opens the file specified for writing and in binary format
with open('QDA_model.pk', 'wb') as f: #this file object is saved in f variable
    pickle.dump(best_model, f)

# %%
#opens specified file for reading and in binary format
with open('QDA_model.pk', 'rb') as f: #this file object is saved in f variable
    loaded_model = pickle.load(f)

# %%
new_data = df.iloc[-2:-1].copy()#copy() is used to generate a copy of the object
new_data.drop('Churn', axis=1, inplace=True)#inplace=True returns nothing and drops the Churn column and updates the data
loaded_model.predict(new_data)
# Out:
# array([1])

# %%
#load_model() is used for loading the trained model
loaded_nb = load_model('QDA')
# Out:
# Transformation Pipeline and Model Successfully Loaded

# %%
#predict_model() is used for making predictions on new_data
predict_model(loaded_nb, new_data)
# Out:
#             tenure  PhoneService  Contract  PaymentMethod  MonthlyCharges  \
# customerID
# 8361-LTMKD     4.0             1         0              1            74.4
#
#             TotalCharges  Label   Score
# customerID
# 8361-LTMKD         306.6      1  0.9089

# %% [markdown]
# MAKING A PYTHON MODULE TO MAKE PREDICTIONS:

# %%
from IPython.display import Code
#python file is created in visual studio for predicting churn for each row on the new_churn_data
Code('predict_churn.py')
# Out:
# import pandas as pd
# from pycaret.classification import predict_model, load_model
#
# def load_data(prepped_churn_data):
#     """
#     Loads churn data into a DataFrame from a string filepath.
#     """
#     df = pd.read_csv(prepped_churn_data, index_col='customerID')
#     return df
#
#
# def make_predictions(df):
#     """
#     Uses the pycaret best model to make predictions on data in the df dataframe.
#     """
#     model = load_model('QDA')
#     predictions = predict_model(model, data=df)
#     predictions.rename({'Label': 'churn_prediction'}, axis=1, inplace=True)
#     predictions['churn_prediction'].replace({1: 'Yes', 0: 'No'},
#                                             inplace=True)
#     return predictions['churn_prediction']
#
#
# if __name__ == "__main__":
#     df = load_data('new_churn_data.csv')
#     predictions = make_predictions(df)
#     print('predictions:')
#     print(predictions)

# %%
#predictions on the new data can be seen by using this magic command  %run
# %run predict_churn.py
# Out:
# Transformation Pipeline and Model Successfully Loaded
# predictions:
# customerID
# 9305-CKSKC    Yes
# 1452-KNGVK     No
# 6723-OKKJM     No
# 7832-POPKP     No
# 6348-TACGU     No
# Name: churn_prediction, dtype: object

# %% [markdown]
# # Summary

# %% [markdown]
# Write a short summary of the process and results here.

# %% [markdown]
# Week-5 Assignment is about using prepped churn data for setting up autoML with pycaret which shows the summary of the entire project, comparing best metric among many using cross-validation, predicting label and score for the best model, saving and loading our model using python built-in module pickle, making predictions on the new data created by using iloc() function and a python file is created for making predictions on the new churn data. I have imported package like pandas and read prepped churn data into dataframe by using read_csv function.
#
# 1.Before setting an autoML with pycaret, I installed python libraries like pycaret and scikit-plot using pip and imported specific functions like setup, compare_models, predict_model, save_model, load_model from pycaret. setup() function initializes the training environment and creates the transformation pipeline. Pycaret setup is initialized by using setup() function which takes two mandatory parameters like data and target. Here, data is prepped_churn_data which is read into pandas dataframe and target is Churn. All other parameters are optional. When Preprocess is set to False, no transformations are applied except for train_test_split and data must be ready for modeling. fold_shuffle=True controls the shuffle parameter of cross validation(CV). fold_shuffle parameter is by default false. The preprocessing and data transformations are configured within the setup function.
#
# 2.AutoML is simply run for finding the best model using compare_models() function. This function evaluates the performance of all metrics available in the model library using cross validation and finds out the best model. sort argument in compare_models is used to choose any other scoring metric, by default it is accuracy. I sorted the table based on the F1 score. Based on the output, the best model is QuadraticDiscriminantAnalysis(qda) which has the highest F1 score(i.e., 61%) and the time taken to run this model is the least while xgboost and lightgbm take longest time to run. best_model is used to display the best model. I tried other metrics too for finding the best model but the score(0.9) and the predictions for the new_churn_data are better using F1 score as the metric.
#
# 3.iloc() function is used to fetch records based on the index values from the datasets. It enables us to retrieve a particular value belonging to a row and column using the index values assigned to it. iloc() function only accepts integer type values as the index values. df.shape() gives the number of rows and columns. df.iloc[start row:end row, start_col:end_col] where end row and end col are excluded. The index values [-2:-1] represents a range, while [-1] is a scalar and a range is a line while a scalar is a point. df.iloc[-1].shape returns 1-D array and df.iloc[-2:-1].shape returns 2-D array. predict_model() function is used to make predictions on the new data (i.e., which is fetched by using iloc() function) by using trained model(i.e., best model(QDA)). This function creates two new columns Label and Score. Label column has its predicted label(1) and Score if it is greater than or equal to 0.5 it is rounded up. The Score is 0.9 and the label is 1 for the new data(i.e., fetched by using iloc()).
#
# 4.The function save_model() in pycaret is used to save our trained model(i.e., QDA). The python built-in module pickle is also used for saving and loading of binary data. I imported pickle and the built-in open function opens a file with the name QDA_model.pk for writing with 'w' and in a binary format using 'b'. The file object is saved in the variable f. The with statement automatically closes the file after the with statement exit , otherwise the function close from the file object f should be called. The data is saved to the file using pickle.
#
# 5.The built-in open function opens a file with the name QDA_model.pk for reading with 'r' and in a binary format using 'b'. The file object is saved in the variable f. The with statement automatically closes the file after the with statement exit , otherwise the function close from the file object f should be called. The pickle's load function(i.e.,pickle.load()) is used for loading the saved data. The new_data is fetched by using iloc() function and the churn column is dropped by using drop() method. axis=0 represents rows and axis=1 represents columns. axis is set to 1 to delete Churn column. copy() function is used to generate a copy of the object. inplace=True does not return anything does the specified operation(deletes the Churn column) and updates the data. inplace=False(by default) returns the copy of the object, the specific operation is performed and then it should be saved to some file. The QDA model which is loaded using pickle load function is used for making predictions on the new_data.
#
# 6.Saving and loading of data can also be done by using pycaret. save_model() in pycaret is used for saving the trained model. load_model() function is used for loading the trained model. The function predict_model() is used for making predictions on new_data by using trained model(i.e., QDA). The score for the new_data is around 0.9 which is good and label is 1(two new columns created by using predict_model function).
#
# 7.I imported code from Ipython.display class for displaying source code. A python file 'predict_churn.py' is created in visual studio for predicting churn for each row on the new_churn_data. The source code in this file is displayed by using Code() from Ipython display module. The magic command  %run is used to run the file predict_churn.py and display the predictions on the new_churn_data. The predictions for the new_churn_data is Yes, No, No, No, No(1,0,0,0,0). The true values for the new_churn_data is 1,0,0,1,0. There is one false negative in the new data. The model(QDA) is working average but not perfect.
